# %%
import tabtools as tabtools



db = tabtools.table_toolkits("/Users/giargiapower/Agent_projects/ToolQA")
print(db.db_loader('flights'))
    #print(db.get_column_names('flights'))
    #print(db.data_filter('IATA_Code_Marketing_Airline=AA, Flight_Number_Marketing_Airline=5647, Origin=BUF, Dest=PHL, FlightDate=2022-04-20'))
    #print(db.get_value('DepTime')) Origin=BOS, Dest=BZN  Flight_Number_Marketing_Airline=4631, FlightDate=2022-06-27
data = db.data_filter('Flight_Number_Marketing_Airline=4631, FlightDate=2022-06-27')
# Out:
# We have successfully loaded the flights database, including the following columns: FlightDate, Airline, Origin, Dest, Cancelled, Diverted, CRSDepTime, DepTime, DepDelayMinutes, DepDelay, ArrTime, ArrDelayMinutes, AirTime, CRSElapsedTime, ActualElapsedTime, Distance, Year, Quarter, Month, DayofMonth, DayOfWeek, Marketing_Airline_Network, Operated_or_Branded_Code_Share_Partners, DOT_ID_Marketing_Airline, IATA_Code_Marketing_Airline, Flight_Number_Marketing_Airline, Operating_Airline, DOT_ID_Operating_Airline, IATA_Code_Operating_Airline, Tail_Number, Flight_Number_Operating_Airline, OriginAirportID, OriginAirportSeqID, OriginCityMarketID, OriginCityName, OriginState, OriginStateFips, OriginStateName, OriginWac, DestAirportID, DestAirportSeqID, DestCityMarketID, DestCityName, DestState, DestStateFips, DestStateName, DestWac, DepDel15, DepartureDelayGroups, DepTimeBlk, TaxiOut, WheelsOff, WheelsOn, TaxiIn, CRSArrTime, ArrDelay, ArrDel15, ArrivalDelayGroups, ArrTimeBlk, DistanceGroup, DivAirportLandings.
#
#  Flight_Number_Marketing_Airline
#
#
#  FlightDate

# %%
import pandas as pd

#data[data['FlightDate']== 2022-06-27]type()
temp = data[1]
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
temp
# Out:
#          FlightDate                Airline Origin Dest Cancelled Diverted  \
# 2349391  2022-06-27  SkyWest Airlines Inc.    BOI  DEN     False    False
# 2749702  2022-06-27      Republic Airlines    GSO  LGA     False    False
# 2749728  2022-06-27      Republic Airlines    LGA  GSO     False    False
# 2773628  2022-06-27      Endeavor Air Inc.    RDU  JFK     False    False
#
#         CRSDepTime DepTime DepDelayMinutes DepDelay ArrTime ArrDelayMinutes  \
# 2349391       1732  1723.0             0.0     -9.0  1920.0             0.0
# 2749702       1106  1102.0             0.0     -4.0  1303.0            19.0
# 2749728        840   830.0             0.0    -10.0  1005.0             0.0
# 2773628       1632  1759.0            87.0     87.0  2008.0            98.0
#
#         AirTime CRSElapsedTime ActualElapsedTime Distance  Year Quarter Month  \
# 2349391    92.0          122.0             117.0    649.0  2022       2     6
# 2749702    74.0           98.0             121.0    461.0  2022       2     6
# 2749728    72.0          107.0              95.0    461.0  2022       2     6
# 2773628    72.0          118.0             129.0    427.0  2022       2     6
#
#         DayofMonth DayOfWeek Marketing_Airline_Network  \
# 2349391         27         1                        UA
# 2749702         27         1                        AA
# 2749728         27         1                        AA
# 2773628         27         1                        DL
#
#         Operated_or_Branded_Code_Share_Partners DOT_ID_Marketing_Airline  \
# 2349391                            UA_CODESHARE                    19977
# 2749702                            AA_CODESHARE                    19805
# 2749728                            AA_CODESHARE                    19805
# 2773628                            DL_CODESHARE                    19790
#
#         IATA_Code_Marketing_Airline Flight_Number_Marketing_Airline  \
# 2349391                          UA                            4631
# 2749702                          AA                            4631
# 2749728                          AA                            4631
# 2773628                          DL                            4631
#
#         Operating_Airline DOT_ID_Operating_Airline  \
# 2349391                OO                    20304
# 2749702                YX                    20452
# 2749728                YX                    20452
# 2773628                9E                    20363
#
#         IATA_Code_Operating_Airline Tail_Number  \
# 2349391                          OO      N607UX
# 2749702                          YX      N869RW
# 2749728                          YX      N869RW
# 2773628                          9E      N908XJ
#
#         Flight_Number_Operating_Airline OriginAirportID OriginAirportSeqID  \
# 2349391                            4631           10713            1071302
# 2749702                            4631           11995            1199502
# 2749728                            4631           12953            1295304
# 2773628                            4631           14492            1449202
#
#         OriginCityMarketID             OriginCityName OriginState  \
# 2349391              30713                  Boise, ID          ID
# 2749702              31995  Greensboro/High Point, NC          NC
# 2749728              31703               New York, NY          NY
# 2773628              34492         Raleigh/Durham, NC          NC
#
#         OriginStateFips OriginStateName OriginWac DestAirportID  \
# 2349391              16           Idaho        83         11292
# 2749702              37  North Carolina        36         12953
# 2749728              36        New York        22         11995
# 2773628              37  North Carolina        36         12478
#
#         DestAirportSeqID DestCityMarketID               DestCityName  \
# 2349391          1129202            30325                 Denver, CO
# 2749702          1295304            31703               New York, NY
# 2749728          1199502            31995  Greensboro/High Point, NC
# 2773628          1247805            31703               New York, NY
#
#         DestState DestStateFips   DestStateName DestWac DepDel15  \
# 2349391        CO             8        Colorado      82      0.0
# 2749702        NY            36        New York      22      0.0
# 2749728        NC            37  North Carolina      36      0.0
# 2773628        NY            36        New York      22      1.0
#
#         DepartureDelayGroups DepTimeBlk TaxiOut WheelsOff WheelsOn TaxiIn  \
# 2349391                 -1.0  1700-1759    10.0    1733.0   1905.0   15.0
# 2749702                 -1.0  1100-1159    32.0    1134.0   1248.0   15.0
# 2749728                 -1.0  0800-0859    15.0     845.0    957.0    8.0
# 2773628                  5.0  1600-1659    21.0    1820.0   1932.0   36.0
#
#         CRSArrTime ArrDelay ArrDel15 ArrivalDelayGroups ArrTimeBlk  \
# 2349391       1934    -14.0      0.0               -1.0  1900-1959
# 2749702       1244     19.0      1.0                1.0  1200-1259
# 2749728       1027    -22.0      0.0               -2.0  1000-1059
# 2773628       1830     98.0      1.0                6.0  1800-1859
#
#         DistanceGroup DivAirportLandings
# 2349391             3                  0
# 2749702             2                  0
# 2749728             2                  0
# 2773628             2                  0
